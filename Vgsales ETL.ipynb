# %%
import pandas as pd

# %%
df =(r"C:\Git_test\Digital Native Challenge\vgsales.csv") pd.read_csv

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
platform_rename_map = {
    "PS2":  "PlayStation 2",
    "X360": "Xbox 360",
    "PS3":  "PlayStation 3",
    "Wii":  "Wii",
    "DS":   "Nintendo DS",
    "PS":   "PlayStation 1",
    "GBA":  "Game Boy Advance",
    "PS4":  "PlayStation 4",
    "PCFX": "PC-FX Interactive",
    "GB":   "Game Boy",
    "XB":   "Xbox Original",
    "NES":  "Nintendo Entertainment System",
    "3DS":  "Nintendo 3DS",
    "N64":  "Nintendo 64",
    "SNES": "Super Nintendo Entertainment System",
    "GEN":  "Sega Genesis",
    "XOne": "Xbox One",
    "2600": "Atari 2600",
    "WiiU": "Wii U",
    "PSP":  "PlayStation Portable",
    "SAT":  "Sega Saturn",
    "DC":   "Dreamcast",
    "SCD":  "Sega CD Video",
    "NG":   "Neo Geo",
    "WS":   "Wonder Swan",
    "TG16": "Turbo Grafx 16",
    "3DO":  "3DO Interactive",
    "GG":   "Game Gear",
    "PC":   "Portable Computer",
    "GC":   "GameCube",
    "3DS":  "Nintendo 3DS",
    "PC": "Personal Computer",
    "PSV": "PlayStation Vita",

}


df["Platform"] = df["Platform"].map(platform_rename_map)


print(df['Platform'])
# Out:
# 0                                  Wii
# 1        Nintendo Entertainment System
# 2                                  Wii
# 3                                  Wii
# 4                             Game Boy
#                      ...
# 16593                 Game Boy Advance
# 16594                         GameCube
# 16595                    PlayStation 2
# 16596                      Nintendo DS
# 16597                 Game Boy Advance
# Name: Platform, Length: 16598, dtype: object

# %%
df['Year'].head(10)
# Out:
# 0    2006.0
# 1    1985.0
# 2    2008.0
# 3    2009.0
# 4    1996.0
# 5    1989.0
# 6    2006.0
# 7    2006.0
# 8    2009.0
# 9    1984.0
# Name: Year, dtype: float64

# %%
min_year = df['Year'].min()
max_year = df['Year'].max()

print(f"Year range in data: {min_year} to {max_year}")
# Out:
# Year range in data: 1980.0 to 2020.0

# %%
sales_rename_map = {
    "EU_Sales": "Europe Sales",
    "JP_Sales": "Asia Sales",
    "Global_Sales": "Global Sales",
    "Other_Sales": "Africa Sales",
    "NA_Sales": "America Sales"
}

df = df.rename(columns=sales_rename_map)
print(df.columns)
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher',
#        'America Sales', 'Europe Sales', 'Asia Sales', 'Africa Sales',
#        'Global Sales'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# Rank               0
# Name               0
# Platform           0
# Year             271
# Genre              0
# Publisher         58
# America Sales      0
# Europe Sales       0
# Asia Sales         0
# Africa Sales       0
# Global Sales       0
# dtype: int64

# %%
NA_rows = df[df['Year'].isna()].index.tolist()

NA_rows
# Out:
# [179,
#  377,
#  431,
#  470,
#  607,
#  624,
#  649,
#  652,
#  711,
#  782,
#  1126,
#  1133,
#  1303,
#  1433,
#  1498,
#  1513,
#  1585,
#  1649,
#  1697,
#  1837,
#  1990,
#  2019,
#  2086,
#  2113,
#  2114,
#  2134,
#  2145,
#  2173,
#  2286,
#  2295,
#  2415,
#  2422,
#  2484,
#  2497,
#  2528,
#  2586,
#  2776,
#  2786,
#  2838,
#  2947,
#  3049,
#  3141,
#  3194,
#  3217,
#  3238,
#  3346,
#  3421,
#  3468,
#  3501,
#  3715,
#  3753,
#  3880,
#  3952,
#  4145,
#  4151,
#  4199,
#  4232,
#  4330,
#  4378,
#  4380,
#  4469,
#  4472,
#  4536,
#  4683,
#  4791,
#  4797,
#  4858,
#  4865,
#  4934,
#  5061,
#  5078,
#  5162,
#  5171,
#  5195,
#  5196,
#  5240,
#  5302,
#  5508,
#  5618,
#  5625,
#  5657,
#  5669,
#  5769,
#  5798,
#  5838,
#  5861,
#  5870,
#  5901,
#  5913,
#  6042,
#  6125,
#  6153,
#  6195,
#  6211,
#  6272,
#  6283,
#  6314,
#  6316,
#  6319,
#  6401,
#  6496,
#  6647,
#  6777,
#  6806,
#  6832,
#  6919,
#  6926,
#  6937,
#  6966,
#  6968,
#  7035,
#  7181,
# ...

# %%
df[df['Year'].isna()][['Global Sales']]
# Out:
#        Global Sales
# 179            5.23
# 377            3.49
# 431            3.17
# 470            3.00
# 607            2.53
# ...             ...
# 16307          0.01
# 16327          0.01
# 16366          0.01
# 16427          0.01
# 16493          0.01
#
# [271 rows x 1 columns]

# %%
print(df['Year'])
# Out:
# 0        2006.0
# 1        1985.0
# 2        2008.0
# 3        2009.0
# 4        1996.0
#           ...
# 16593    2002.0
# 16594    2003.0
# 16595    2008.0
# 16596    2010.0
# 16597    2003.0
# Name: Year, Length: 16598, dtype: float64

# %%
print (df['Year'].dtype)
# Out:
# float64

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y')
print (df['Year'].dtype)
# Out:
# datetime64[ns]

# %%
print(df['Publisher'].isna().sum())
# Out:
# 58

# %%
df['Publisher'] = df['Publisher'].fillna('Unknown')

# %%
print(df['Publisher'].isna().sum())
# Out:
# 0

# %%
print (df['Global Sales'].dtype)
# Out:
# float64

# %%
df['Global Sales'] = df['Global Sales'].apply(lambda x: f"{x: .2f}")

# %%
df.to_csv(r"C:\Git_test\Digital Native Challenge\Vgsales_Cleaned_Data_test.csv", index=False)
